# %%
'''
 This program aims to get the same functionality as the one described
 in the book Alfresco One 5.x Developer's guide

 Author: Ignacio De Bonis
'''
import cmislib
from cmislib.model import CmisClient
import base64

# %%
# user credentials
userName = 'admin'
userPass = 'admin'

#connection settings
repositoryUrl = 'http://localhost:8080/alfresco/api/-default-/public/cmis/versions/1.1/atom'

try:
    
    # create session
    client = CmisClient(repositoryUrl, userName, userPass)
    repo = client.defaultRepository
    
    # createDocument(repo)
    # searchDocuments(repo, 1)

except Exception as exception: 
    print(type(exception).__name__ )

# %%
def createDocument(session):
    # Create a Marketing folder with a text file
    # Locate document library
    path = '/Sites/marketing/documentLibrary'
    documentLibrary = session.getObjectByPath(path)

    # Locate the marketing folder
    marketingFolder = None
    for child in documentLibrary.getChildren():
        if child.name == 'Marketing':
            marketingFolder = child

    # create the marketing folder if needed
    if marketingFolder == None:
        marketingFolder = documentLibrary.createFolder('Marketing')

    # prepare properties
    filename = 'My new whitepaper.txt'
    properties = {'cmis:name': filename,
                  'cmis:objectTypeId': 'D:sc:marketingDoc'}

    # prepare content
    content = 'Hello World!'
    mimetype = 'text/plain; charset=UTF-8'

    marketingDocument = marketingFolder.createDocument(name=filename, properties=properties,
                                                       contentFile=str(base64.b64encode(
                                                           content.encode('UTF-8')))[2:-1],
                                                       contentType=mimetype, contentEncoding='UTF-8')

    # Locate the whitepaper folder
    whitepaperFolder = None
    for child in documentLibrary.getChildren():
        if child.name == 'Whitepapers':
            whitepaperFolder = child

    # look for a whitepaper
    if whitepaperFolder != None:
        whitepaper = None
        for child in whitepaperFolder.getChildren():
            if child.properties['cmis:objectTypeId'] == 'D:sc:whitepaper':
                whitepaper = child

        # Create relationship between marketingDocument and whitepaper
        if whitepaper != None:
            relationship = marketingDocument.createRelationship(
                whitepaper, 'R:sc:relatedDocuments')

# %%
def searchDocuments(session, maxItems = 5 ):
    
    # Perform cmis query and print the result properties
    maxItems=str(maxItems)
    results = session.query("SELECT * FROM sc:doc", maxItems=maxItems)
    for hit in results:
        for prop in hit.properties:
            print(prop, ":", hit.properties[prop])
        print('--------------------------------------')

# %%
def deleteDocuments(session):
    # Delete all documents from the Marketing folder
    # Locate document library
    path = '/Sites/marketing/documentLibrary'
    documentLibrary = session.getObjectByPath(path)
    
    # Locate the marketing folder
    marketingFolder = None
    for child in documentLibrary.getChildren():
        if child.name == 'Marketing':
            marketingFolder = child

    # Delete documents in marketing folder
    if marketingFolder != None:
        for child in marketingFolder.getChildren():
            child.delete()

# %%
deleteDocuments(repo)

# %%
# Out:
# alfcmis:nodeRef : workspace://SpacesStore/35363aec-5240-4efc-8574-916ad170b18b
# cmis:isImmutable : False
# cmis:versionLabel : 1.0
# cmis:objectTypeId : D:sc:whitepaper
# cmis:description : None
# cmis:createdBy : admin
# cmis:checkinComment : Initial Version
# cmis:creationDate : 2021-10-08 15:56:48.975000-03:00
# cmis:isMajorVersion : True
# cmis:contentStreamFileName : Test Document.txt
# cmis:name : Test Document.txt
# cmis:isLatestVersion : True
# cmis:lastModificationDate : 2021-10-13 13:24:01.527000-03:00
# cmis:contentStreamLength : 5
# cmis:objectId : 35363aec-5240-4efc-8574-916ad170b18b;1.0
# cmis:lastModifiedBy : admin
# cmis:secondaryObjectTypeIds : P:sys:localized
# cmis:contentStreamId : store://2021/10/8/15/56/9745583c-5c48-472e-933f-cc4782040dd0.bin
# cmis:contentStreamMimeType : application/binary
# cmis:baseTypeId : cmis:document
# cmis:changeToken : None
# cmis:isPrivateWorkingCopy : False
# cmis:versionSeriesCheckedOutBy : None
# cmis:isVersionSeriesCheckedOut : False
# cmis:versionSeriesId : 35363aec-5240-4efc-8574-916ad170b18b
# cmis:isLatestMajorVersion : True
# cmis:versionSeriesCheckedOutId : None
# cmisra:object : None
# --------------------------------------
# alfcmis:nodeRef : workspace://SpacesStore/da6ee017-3043-414f-813f-03cd497fd0c7
# cmis:isImmutable : False
# cmis:versionLabel : 1.0
# cmis:objectTypeId : D:sc:whitepaper
# cmis:description : None
# cmis:createdBy : admin
# cmis:checkinComment : None
# cmis:creationDate : 2021-10-13 13:24:34.524000-03:00
# cmis:isMajorVersion : True
# cmis:contentStreamFileName : Documento de prueba
# cmis:name : Documento de prueba
# cmis:isLatestVersion : True
# cmis:lastModificationDate : 2021-10-13 13:27:45.636000-03:00
# cmis:contentStreamLength : 10
# cmis:objectId : da6ee017-3043-414f-813f-03cd497fd0c7;1.0
# cmis:lastModifiedBy : admin
# cmis:secondaryObjectTypeIds : ['P:sys:incomplete', 'P:cm:generalclassifiable', 'P:cm:titled', 'P:app:inlineeditable', 'P:sys:localized', 'P:cm:author', 'P:sc:webable', 'P:sc:clientRelated']
# cmis:contentStreamId : store://2021/10/13/13/24/7b52927d-1577-4b08-a35b-223e3dfd6f9a.bin
# cmis:contentStreamMimeType : text/plain
# cmis:baseTypeId : cmis:document
# cmis:changeToken : None
# cmis:isPrivateWorkingCopy : False
# cmis:versionSeriesCheckedOutBy : None
# cmis:isVersionSeriesCheckedOut : False
# cmis:versionSeriesId : da6ee017-3043-414f-813f-03cd497fd0c7
# cmis:isLatestMajorVersion : True
# cmis:versionSeriesCheckedOutId : None
# cmisra:object : None
# --------------------------------------
# alfcmis:nodeRef : workspace://SpacesStore/09d7c8b3-b168-4e25-9d36-01e11c683de0
# cmis:isImmutable : False
# cmis:versionLabel : 1.0
# cmis:objectTypeId : D:sc:whitepaper
# cmis:description : None
# cmis:createdBy : admin
# cmis:checkinComment : None
# cmis:creationDate : 2021-10-14 15:15:52.360000-03:00
# cmis:isMajorVersion : True
# cmis:contentStreamFileName : wp- (1634235352526).odt
# cmis:name : wp- (1634235352526).odt
# cmis:isLatestVersion : True
# cmis:lastModificationDate : 2021-10-14 15:15:52.360000-03:00
# cmis:contentStreamLength : 15243
# cmis:objectId : 09d7c8b3-b168-4e25-9d36-01e11c683de0;1.0
# cmis:lastModifiedBy : admin
# cmis:secondaryObjectTypeIds : ['P:cm:titled', 'P:sys:localized', 'P:cm:author', 'P:sc:webable']
# cmis:contentStreamId : store://2021/10/14/15/15/e2be5b67-b880-4b80-9ab9-d0ead9f002df.bin
# cmis:contentStreamMimeType : application/vnd.oasis.opendocument.text
# cmis:baseTypeId : cmis:document
# cmis:changeToken : None
# cmis:isPrivateWorkingCopy : False
# cmis:versionSeriesCheckedOutBy : None
# cmis:isVersionSeriesCheckedOut : False
# cmis:versionSeriesId : 09d7c8b3-b168-4e25-9d36-01e11c683de0
# cmis:isLatestMajorVersion : True
# cmis:versionSeriesCheckedOutId : None
# cmisra:object : None
# --------------------------------------
# alfcmis:nodeRef : workspace://SpacesStore/b4fd1823-2709-4b08-a8cf-e7396b519ab6
# cmis:isImmutable : False
# cmis:versionLabel : 1.0
# cmis:objectTypeId : D:sc:marketingDoc
# cmis:description : None
# cmis:createdBy : admin
# cmis:checkinComment : Initial Version
# cmis:creationDate : 2021-10-19 18:47:29.361000-03:00
# cmis:isMajorVersion : True
# cmis:contentStreamFileName : My new whitepaper.txt
# cmis:name : My new whitepaper.txt
# cmis:isLatestVersion : True
# cmis:lastModificationDate : 2021-10-19 18:47:29.361000-03:00
# cmis:contentStreamLength : 12
# cmis:objectId : b4fd1823-2709-4b08-a8cf-e7396b519ab6;1.0
# cmis:lastModifiedBy : admin
# cmis:secondaryObjectTypeIds : ['P:cm:titled', 'P:sys:localized', 'P:cm:author']
# cmis:contentStreamId : store://2021/10/19/18/47/3b09172b-0fb6-4083-8fe5-4ed6b558e706.bin
# cmis:contentStreamMimeType : text/plain
# cmis:baseTypeId : cmis:document
# cmis:changeToken : None
# cmis:isPrivateWorkingCopy : False
# cmis:versionSeriesCheckedOutBy : None
# cmis:isVersionSeriesCheckedOut : False
# cmis:versionSeriesId : b4fd1823-2709-4b08-a8cf-e7396b519ab6
# cmis:isLatestMajorVersion : True
# cmis:versionSeriesCheckedOutId : None
# cmisra:object : None
# --------------------------------------
